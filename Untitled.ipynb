# %%
import pandas as pd
import numpy as np
import requests 
import sqlalchemy
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:password2544@localhost:5432/heavy_tails_data')

# %%
query = """
SELECT id, secid, shortname, name, typename, isin, faceunit, is_external, primary_boardid, is_qualified_investors, eveningsession, weekendsession
FROM moex_stocks
"""
df_stocks = pd.read_sql(query, engine)

# %%
query = """
SELECT *
FROM moex_daily_history
"""
df = pd.read_sql(query, engine)

# %%
df['tradedate'] = pd.to_datetime(df['tradedate'])

# %%
df['market'].value_counts()
# Out:
# market
# bonds     1683583
# shares     678180
# index      118369
# gcc          6726
# ccp          1721
# ndm            51
# Name: count, dtype: int64

# %%
query = """
SELECT *
FROM moex_dividends
"""
df_dividends = pd.read_sql(query, engine)

# %%
len(df[df['market']=='shares']['secid'].unique())
# Out:
# 312

# %%
len(df_dividends['secid'].unique())
# Out:
# 181

# %%
df_dividends[df_dividends['secid']=='SBER']
# Out:
#         id secid boardid          isin registryclosedate  value currencyid  \
# 1139  1140  SBER    TQBR  RU0009029540        2019-06-13  16.00        RUB
# 1140  1141  SBER    TQBR  RU0009029540        2020-10-05  18.70        RUB
# 1141  1142  SBER    TQBR  RU0009029540        2021-05-12  18.70        RUB
# 1142  1143  SBER    TQBR  RU0009029540        2023-05-11  25.00        RUB
# 1143  1144  SBER    TQBR  RU0009029540        2024-07-11  33.30        RUB
# 1144  1145  SBER    TQBR  RU0009029540        2025-07-18  34.84        RUB
#
#                                                     raw  \
# 1139  {'isin': 'RU0009029540', 'secid': 'SBER', 'val...
# 1140  {'isin': 'RU0009029540', 'secid': 'SBER', 'val...
# 1141  {'isin': 'RU0009029540', 'secid': 'SBER', 'val...
# 1142  {'isin': 'RU0009029540', 'secid': 'SBER', 'val...
# 1143  {'isin': 'RU0009029540', 'secid': 'SBER', 'val...
# 1144  {'isin': 'RU0009029540', 'secid': 'SBER', 'val...
#
#                             loaded_at
# ...

# %%
df[(df['secid']=='SBER') & (df['tradedate']<pd.to_datetime('2019-07-13')) & (df['tradedate']>pd.to_datetime('2019-05-13'))][['tradedate', 'close']]
# Out:
#         tradedate   close
# 696277 2019-05-14  227.88
# 696278 2019-05-15  228.69
# 696279 2019-05-16  228.19
# 696280 2019-05-17  226.94
# 696281 2019-05-20  226.00
# 696282 2019-05-21  232.71
# 696283 2019-05-22  235.86
# 696284 2019-05-23  229.30
# 696285 2019-05-24  234.45
# 696286 2019-05-27  236.00
# 696287 2019-05-28  233.19
# 696288 2019-05-29  233.40
# 696289 2019-05-30  232.75
# 696290 2019-05-31  233.24
# 696291 2019-06-03  239.95
# 696292 2019-06-04  236.00
# 696293 2019-06-05  239.00
# 696294 2019-06-06  244.89
# 696295 2019-06-07  248.28
# 696296 2019-06-10  249.00
# 696297 2019-06-11  235.89
# 696298 2019-06-13  240.49
# 696299 2019-06-14  238.80
# 696300 2019-06-17  237.80
# 696301 2019-06-18  241.80
# 696302 2019-06-19  240.40
# 696303 2019-06-20  244.10
# 696304 2019-06-21  238.02
# 696305 2019-06-24  239.09
# 696306 2019-06-25  236.70
# 696307 2019-06-26  240.59
# 696308 2019-06-27  240.50
# 696309 2019-06-28  238.55
# 696310 2019-07-01  242.98
# ...

# %%
query = """
SELECT *
FROM moex_daily_returns
"""
df = pd.read_sql(query, engine)

# %%
df['boardid'].value_counts()
# Out:
# boardid
# TQCB    1334610
# TQBR     644759
# TQOB      81694
# INAV      70657
# INPF      36105
# TQTF      32280
# GCRP       6717
# AGRO       5336
# TQRD       4832
# MMIX       4094
# TQOY       3544
# TQOD       3160
# EQRP       1712
# TQTY        604
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'secid', 'boardid', 'tradedate', 'daily_return', 'loaded_at'], dtype='object')
